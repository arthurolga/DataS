# %% [markdown]
#  Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Arthur Quintella de Mello Olga

# %% [markdown]
# # Análise de Segurança Alimentar por Região, Renda e Tipo de Moradia

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import math

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\arthu\Downloads\CD Projeto 1

# %%
dados = pd.read_csv('DOM2013.csv')


##  Pessoas por Região

dados.loc[(dados.UF>10)&(dados.UF<18),'REGIAO']='Norte'
dados.loc[(dados.UF>20)&(dados.UF<30),'REGIAO']='Nordeste'
dados.loc[(dados.UF>30)&(dados.UF<40),'REGIAO']='Sudeste'
dados.loc[(dados.UF>40)&(dados.UF<50),'REGIAO']='Sul'
dados.loc[(dados.UF>50),'REGIAO']='Centro-Oeste'

dados.REGIAO = dados.REGIAO.astype('category')


##  Pessoas que já tiveram algum problema em relação à comida como excassez parcial ou total e situações de limite

dados.loc[(dados.V2103==1)|(dados.V2105==1)|(dados.V2107==1)|(dados.V2109==1),"FOME"]="Sim"
dados.loc[(dados.V2103==3)|(dados.V2105==3)|(dados.V2107==3)|(dados.V2109==3),"FOME"]="Não"
dados.loc[(dados.V2103!=1) & (dados.V2103!=3),"FOME"]="Sem Reposta"


dados.FOME = dados.FOME.astype('category')

dados.loc[(dados.V4622 == 0),'SAL']='Sem renda'
for i in range(1,7):
    dados.loc[(dados.V4622 == i),'SAL']=str(0.5*i)

dados.SAL = dados.SAL.astype('category')
#dados.SAL

#  Existência de Banheiros
#V0215 1 sim 3 nao
dados.loc[(dados.V0215 == 1),'BANHEIROS'] = "Sim"
dados.loc[(dados.V0215 == 3),'BANHEIROS'] = 'Não'
dados.loc[(dados.V0215 != 1) & (dados.V0215 != 3),'BANHEIROS'] = 'Sem Resposta'

#dados.BANHEIROS.tail()

#  Faixa salarial do domicilio


#V0203 1 alvenaria 2 madeira aparelhada 3 taipa n revestida 4 madeira aproveitada 5 palha aproveitada

dados.loc[(dados.V0203 == 1),'MATERIAL'] = 'Alvenaria'
dados.loc[(dados.V0203 == 2),'MATERIAL'] = 'Madeira Aparelhada'
dados.loc[(dados.V0203 == 3),'MATERIAL'] = 'Taipa Não Revestida'
dados.loc[(dados.V0203 == 4),'MATERIAL'] = 'Madeira Aproveitada'
dados.loc[(dados.V0203 == 5),'MATERIAL'] = 'Palha Aproveitada'

#dados.MATERIAL

# Salário Bruto

#dados['V4614'] = dados['SALBRUTO']
dados = dados.rename(columns = {'V4614':'RENDA_BRUTA'})
#dados.RENDA_BRUTA

# Movendo para um novo dataframe
#dados.columns
df = dados.loc[:, ['REGIAO','FOME','SAL','RENDA_BRUTA','BANHEIROS','MATERIAL']]
df
# Out:
#               REGIAO         FOME  SAL   RENDA_BRUTA     BANHEIROS  \
# 0              Norte  Sem Reposta  NaN           NaN  Sem Resposta
# 1              Norte  Sem Reposta  NaN           NaN  Sem Resposta
# 2              Norte          Não  1.5  3.500000e+02           Sim
# 3              Norte          Não  1.0  6.780000e+02           Sim
# 4              Norte          Não  1.0  8.000000e+02           Sim
# 5              Norte          Não  1.5  8.000000e+02           Sim
# 6              Norte          Não  1.5  1.234000e+03           Sim
# 7              Norte          Não  2.0  4.000000e+03           Sim
# 8              Norte          Não  2.5  3.500000e+03           Sim
# 9              Norte          Não  2.0  1.300000e+03           Sim
# 10             Norte          Não  1.0  1.400000e+03           Sim
# 11             Norte          Não  1.0  1.000000e+03           Sim
# 12             Norte          Não  2.0  1.100000e+03           Sim
# 13             Norte  Sem Reposta  NaN           NaN  Sem Resposta
# 14             Norte          Não  1.5  1.300000e+03           Sim
# 15             Norte          Não  1.5  6.780000e+02           Sim
# 16             Norte          Não  3.0  3.000000e+03           Sim
# 17             Norte          Não  2.0  5.000000e+03           Sim
# 18             Norte          Não  2.0  1.178000e+03           Sim
# 19             Norte          Não  1.5  5.000000e+02           Sim
# 20             Norte          Não  1.5  2.000000e+03           Sim
# 21             Norte          Não  2.5  2.978000e+03           Sim
# 22             Norte          Não  2.5  1.500000e+03           Sim
# 23             Norte  Sem Reposta  NaN           NaN  Sem Resposta
# 24             Norte          Não  3.0  2.410000e+03           Sim
# 25             Norte          Não  1.5  4.606000e+03           Sim
# 26             Norte          Não  1.0  1.356000e+03           Sim
# 27             Norte  Sem Reposta  NaN           NaN  Sem Resposta
# 28             Norte          Não  2.0  4.800000e+03           Sim
# 29             Norte          Não  2.0  3.200000e+03           Sim
# ...              ...          ...  ...           ...           ...
# 148667  Centro-Oeste          Não  NaN  1.000000e+12           Sim
# 148668  Centro-Oeste          Não  NaN  8.000000e+03           Sim
# 148669  Centro-Oeste          Não  NaN  2.350000e+04           Sim
# 148670  Centro-Oeste          Não  NaN  1.000000e+12           Sim
# 148671  Centro-Oeste          Não  NaN  1.000000e+12           Sim
# 148672  Centro-Oeste          Não  NaN  2.500000e+04           Sim
# 148673  Centro-Oeste          Não  NaN  1.000000e+12           Sim
# 148674  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148675  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148676  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148677  Centro-Oeste          Não  NaN  1.300000e+04           Sim
# 148678  Centro-Oeste          Não  NaN  1.400000e+04           Sim
# 148679  Centro-Oeste          Não  NaN  5.520000e+04           Sim
# 148680  Centro-Oeste          Não  1.5  1.615000e+03           Sim
# 148681  Centro-Oeste          Não  0.5  6.000000e+02           Sim
# 148682  Centro-Oeste          Não  2.0  1.300000e+03           Sim
# 148683  Centro-Oeste          Não  2.0  7.500000e+02           Sim
# 148684  Centro-Oeste          Não  1.5  3.000000e+03           Sim
# 148685  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148686  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148687  Centro-Oeste          Não  1.5  1.780000e+03           Sim
# 148688  Centro-Oeste          Não  2.0  4.870000e+03           Sim
# 148689  Centro-Oeste          Não  2.0  4.500000e+03           Sim
# 148690  Centro-Oeste          Sim  1.5  1.550000e+03           Sim
# 148691  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
# 148692  Centro-Oeste          Sim  2.0  2.400000e+03           Sim
# 148693  Centro-Oeste          Não  0.5  1.000000e+02           Sim
# 148694  Centro-Oeste          Não  1.5  1.550000e+03           Sim
# 148695  Centro-Oeste          Não  1.5  8.000000e+02           Sim
# 148696  Centro-Oeste  Sem Reposta  NaN           NaN  Sem Resposta
#
#                   MATERIAL
# 0                      NaN
# 1                      NaN
# 2                Alvenaria
# 3       Madeira Aparelhada
# 4                Alvenaria
# 5                Alvenaria
# 6                Alvenaria
# 7                Alvenaria
# 8                Alvenaria
# 9                Alvenaria
# 10      Madeira Aparelhada
# 11               Alvenaria
# 12      Madeira Aparelhada
# 13                     NaN
# 14               Alvenaria
# 15               Alvenaria
# 16               Alvenaria
# 17               Alvenaria
# 18      Madeira Aparelhada
# 19               Alvenaria
# 20               Alvenaria
# 21               Alvenaria
# 22      Madeira Aparelhada
# 23                     NaN
# 24               Alvenaria
# 25               Alvenaria
# 26      Madeira Aparelhada
# 27                     NaN
# 28      Madeira Aparelhada
# 29               Alvenaria
# ...                    ...
# 148667           Alvenaria
# 148668           Alvenaria
# 148669           Alvenaria
# 148670           Alvenaria
# 148671           Alvenaria
# 148672           Alvenaria
# 148673           Alvenaria
# 148674                 NaN
# 148675                 NaN
# 148676                 NaN
# 148677           Alvenaria
# 148678           Alvenaria
# 148679           Alvenaria
# 148680           Alvenaria
# 148681           Alvenaria
# 148682           Alvenaria
# 148683           Alvenaria
# 148684           Alvenaria
# 148685                 NaN
# 148686                 NaN
# 148687           Alvenaria
# 148688           Alvenaria
# 148689           Alvenaria
# 148690           Alvenaria
# 148691                 NaN
# 148692           Alvenaria
# 148693           Alvenaria
# 148694           Alvenaria
# 148695           Alvenaria
# 148696                 NaN
#
# [148697 rows x 6 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
